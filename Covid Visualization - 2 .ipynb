# %%
#import pycountry
#import plotly.express as px
import matplotlib.pyplot as plt
import pandas as pd
URL_DATASET = r'https://raw.githubusercontent.com/datasets/covid-19/master/data/countries-aggregated.csv'
df1 = pd.read_csv(URL_DATASET)


print(df1.head(3))  # Get first 3 entries in the dataframe
# Out:
#          Date      Country  Confirmed  Recovered  Deaths
# 0  2020-01-22  Afghanistan          0          0       0
# 1  2020-01-22      Albania          0          0       0
# 2  2020-01-22      Algeria          0          0       0

# %%
print(df1.tail(3))  # Get last 3 entries in the dataframe
# Out:
#              Date   Country  Confirmed  Recovered  Deaths
# 31017  2020-07-04     Yemen       1248        537     337
# 31018  2020-07-04    Zambia       1632       1348      30
# 31019  2020-07-04  Zimbabwe        698        181       8

# %%
#df1.to_csv(r'C:\Users\admin\Documents\covid visualization 2 index false.csv')

# %%
df1['Total Cases'] = df1[['Confirmed','Recovered','Deaths']].sum(axis=1)

# %%
df_IN = df1[df1['Country'] == 'India']

df_IN.head(3)


df_IN_Final = df_IN.tail(99)

# %%
plt.rcParams["figure.figsize"]=20,20

# %%
# Plot column 'Confirmed'
df_IN_Final.plot(kind = 'bar', x = 'Date', y = 'Confirmed', color = 'blue')

# %%
ax1 = plt.gca()
df_IN_Final.plot(kind = 'bar', x = 'Date', y = 'Deaths', color = 'red', ax = ax1)

# %%
plt.show()
